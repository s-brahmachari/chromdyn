# %%
from pathlib import Path
SRC = Path("/home") / "sb95" / "ChromatinDynamics" / "src"
if SRC.exists():
    import sys
    sys.path.append(str(SRC))
    from Topology import TopologyGenerator
    from ChromatinDynamics import ChromatinDynamics
else:
    print(SRC, "does not exist")
import numpy as np
import pandas as pd

# %%
d=np.array([[ii, 'H'] for ii in range(10)], dtype=str).reshape(10,2)
np.savetxt("seq.txt", d, fmt='%s')

# %%
generator = TopologyGenerator()
generator.gen_top(chain_lens=[471, 977, 1205, 27], chain_names=['chrX','chr2','chr3','chr4'], types="unique")
generator.save_top()

# %%
assert None
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 assert None
#
# AssertionError:

# %%
d=Path("/home/sb95/ChromatinDynamics/requirements.txt")

# %%
d.exists()
# Out:
# True

# %%
int('sd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int('sd')
#
# ValueError: invalid literal for int() with base 10: 'sd'

# %%
class ravioli:
    def __init__(self,):
        self.h=8
        
        pass

# %%
d=ravioli()
hasattr(d,'h')
# Out:
# True

# %%
(1_000_000/6000)
# Out:
# 166.66666666666666

# %%
hic_exp = np.loadtxt("/work/cms16/sb95/Drosophila/input_data/WT.txt")

# %%
guess_lambda = -0.5*hic_exp

# %%
# ld = -0.1 * np.ones(shape=(2680, 2680),)

df = pd.DataFrame(guess_lambda, columns=[f'M{xx}' for xx in range(1,2681)])

# %%
df.to_csv('/work/cms16/sb95/Drosophila/input_data/lambda_linear_guess', index=False)

# %%
np.loadtxt('/work/cms16/sb95/Drosophila/input_data/WT.txt').shape
# Out:
# (2680, 2680)

# %%
h=np.loadtxt("/work/cms16/sb95/Drosophila/WT_optimize_eta0.03/output_1/run_1/Pi_1_1.txt")

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(np.log10(h))

# %%
(1_000_000/2000)/60
# Out:
# 8.333333333333334
