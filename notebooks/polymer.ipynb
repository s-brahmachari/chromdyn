# %%
import sys
sys.path.append('/home/sb95/ChromatinDynamics')
from topology import TopologyGenerator
from ChromatinDynamics import ChromatinDynamics
import openmm.unit as unit
import numpy as np

# %%
generator = TopologyGenerator()
generator.gen_top([1000])

# %%
Rg = [] 
positions=[]
num_blocks = 5
name='saw_LJ'
for idx, xx in enumerate([1.0, 0.5]):
    Rg.append([])
    for replica in range(1):
        sim = ChromatinDynamics(generator.topology, integrator='langevin', platform_name="OpenCL", output_dir=f"{name}_{replica}", log_file=f"chrom_dynamics_{replica}.log")
        sim.system_setup(mode=name, chi=0.0, r_rep=xx)
        sim.simulation_setup()
        sim.run(10000) #relax
        for _ in range(num_blocks):
            sim.run(2000)
            sim.print_force_info()
            state = sim.simulation.context.getState(getPositions=True)
            pos = state.getPositions(asNumpy=True).value_in_unit(unit.nanometers)
            positions.append(pos)
            Rg[idx].append(sim.analyzer.compute_RG())
# np.savetxt("./Radius_of_gyration.txt", Rg)
for val in Rg:
    print(np.mean(val), np.std(val))
# Out:
# 2025-03-27 12:25:44,105 | INFO | ChromatinDynamics | ************************************************************
# 2025-03-27 12:25:44,106 | INFO | ChromatinDynamics |                      Chromatin Dynamics
# 2025-03-27 12:25:44,106 | INFO | ChromatinDynamics | ************************************************************
# 2025-03-27 12:25:44,107 | WARNING | platforms | Requested platform 'OpenCL' not found. Available platforms: Reference, CPU. Defaulting to first available platform.
# 2025-03-27 12:25:44,108 | INFO | platforms | ------------------------------------------------------------
# 2025-03-27 12:25:44,108 | INFO | integrators | IntegratorManager initialized
# 2025-03-27 12:25:44,109 | INFO | integrators | Valid integrators: ['brownian', 'langevin', 'active']
# 2025-03-27 12:25:44,110 | INFO | integrators | ------------------------------------------------------------
# 2025-03-27 12:25:44,111 | INFO | ChromatinDynamics | Setting up system with mode='saw_LJ'
# 2025-03-27 12:25:44,111 | INFO | ChromatinDynamics | Adding 1000 particles ...
# 2025-03-27 12:25:44,112 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:25:44,114 | INFO | forcefield | Adding 999 harmonic bonds with parameters:
# 2025-03-27 12:25:44,114 | INFO | forcefield | length: 1.0, spring constant (k): 30.0, group: 0
# 2025-03-27 12:25:44,115 | INFO | forcefield | HarmonicBonds force successfully added to system.
# 2025-03-27 12:25:44,115 | INFO | forcefield | --------------------------------------------------
# 2025-03-27 12:25:44,116 | INFO | forcefield | Adding Hard-core repulsion force with parameters:
# 2025-03-27 12:25:44,117 | INFO | forcefield | sigma=1.0, cutoff=3.0, group=6
# 2025-03-27 12:25:44,119 | INFO | forcefield | Added exclusions from bonded monomers.
# 2025-03-27 12:25:44,119 | INFO | forcefield | HardCoreLJ force successfully added to system.
# 2025-03-27 12:25:44,120 | INFO | forcefield | --------------------------------------------------
# 2025-03-27 12:25:44,120 | INFO | ChromatinDynamics | System set up complete!
# 2025-03-27 12:25:44,121 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:25:44,121 | INFO | integrators | LangevinIntegrator: temperatute=120.0 | friction=0.1 | timestep=0.01
# 2025-03-27 12:25:44,124 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:25:44,126 | INFO | ChromatinDynamics | Setting up context...
# 2025-03-27 12:25:44,126 | INFO | ChromatinDynamics | Random position initialization in context
# 2025-03-27 12:25:44,148 | INFO | ChromatinDynamics | Walk completed after 1 attempt(s). Position shape: (1000, 3)
# 2025-03-27 12:25:44,148 | INFO | ChromatinDynamics | Simulation set up complete!
# 2025-03-27 12:25:44,149 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:25:44,149 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:25:44,150 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:25:44,150 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:25:44,152 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.000
# 2025-03-27 12:25:44,157 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.407
# 2025-03-27 12:25:44,158 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:25:44,158 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 0.001
# 2025-03-27 12:25:44,158 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:25:44,160 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:25:44,160 | INFO | ChromatinDynamics | Running simulation for 10000 steps...
# 2025-03-27 12:26:18,125 | INFO | ChromatinDynamics | Completed 10000 steps in 33.96s (294 steps/s) | Radius of gyration: 21.03
# 2025-03-27 12:26:18,126 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:18,126 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:18,127 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:26:24,738 | INFO | ChromatinDynamics | Completed 2000 steps in 6.61s (303 steps/s) | Radius of gyration: 21.35
# 2025-03-27 12:26:24,740 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:24,740 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:24,741 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:26:24,742 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:24,745 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.576
# 2025-03-27 12:26:24,749 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.055
# 2025-03-27 12:26:24,750 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:24,750 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.505
# 2025-03-27 12:26:24,751 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:24,753 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:24,753 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:26:31,192 | INFO | ChromatinDynamics | Completed 2000 steps in 6.44s (311 steps/s) | Radius of gyration: 22.24
# 2025-03-27 12:26:31,193 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:31,193 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:31,194 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:26:31,194 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:31,195 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.578
# 2025-03-27 12:26:31,198 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.049
# 2025-03-27 12:26:31,199 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:31,199 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.477
# 2025-03-27 12:26:31,200 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:31,201 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:31,201 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:26:37,585 | INFO | ChromatinDynamics | Completed 2000 steps in 6.38s (313 steps/s) | Radius of gyration: 22.20
# 2025-03-27 12:26:37,587 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:37,587 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:37,587 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:26:37,588 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:37,589 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.609
# 2025-03-27 12:26:37,592 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.046
# 2025-03-27 12:26:37,593 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:37,594 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.442
# 2025-03-27 12:26:37,594 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:37,595 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:37,595 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:26:44,073 | INFO | ChromatinDynamics | Completed 2000 steps in 6.48s (309 steps/s) | Radius of gyration: 21.85
# 2025-03-27 12:26:44,074 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:44,074 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:44,075 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:26:44,075 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:44,076 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.564
# 2025-03-27 12:26:44,080 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.058
# 2025-03-27 12:26:44,080 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:44,081 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.493
# 2025-03-27 12:26:44,081 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:44,082 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:44,082 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:26:50,548 | INFO | ChromatinDynamics | Completed 2000 steps in 6.47s (309 steps/s) | Radius of gyration: 22.10
# 2025-03-27 12:26:50,549 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:50,550 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:50,551 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:26:50,551 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:50,552 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.542
# 2025-03-27 12:26:50,560 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.052
# 2025-03-27 12:26:50,560 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:50,561 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.471
# 2025-03-27 12:26:50,561 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:50,569 | INFO | ChromatinDynamics | ************************************************************
# 2025-03-27 12:26:50,570 | INFO | ChromatinDynamics |                      Chromatin Dynamics
# 2025-03-27 12:26:50,571 | INFO | ChromatinDynamics | ************************************************************
# 2025-03-27 12:26:50,571 | WARNING | platforms | Requested platform 'OpenCL' not found. Available platforms: Reference, CPU. Defaulting to first available platform.
# 2025-03-27 12:26:50,571 | INFO | platforms | ------------------------------------------------------------
# 2025-03-27 12:26:50,572 | INFO | integrators | IntegratorManager initialized
# 2025-03-27 12:26:50,572 | INFO | integrators | Valid integrators: ['brownian', 'langevin', 'active']
# 2025-03-27 12:26:50,572 | INFO | integrators | ------------------------------------------------------------
# 2025-03-27 12:26:50,574 | INFO | ChromatinDynamics | Setting up system with mode='saw_LJ'
# 2025-03-27 12:26:50,574 | INFO | ChromatinDynamics | Adding 1000 particles ...
# 2025-03-27 12:26:50,575 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:50,577 | INFO | forcefield | Adding 999 harmonic bonds with parameters:
# 2025-03-27 12:26:50,577 | INFO | forcefield | length: 1.0, spring constant (k): 30.0, group: 0
# 2025-03-27 12:26:50,577 | INFO | forcefield | HarmonicBonds force successfully added to system.
# 2025-03-27 12:26:50,578 | INFO | forcefield | --------------------------------------------------
# 2025-03-27 12:26:50,579 | INFO | forcefield | Adding Hard-core repulsion force with parameters:
# 2025-03-27 12:26:50,579 | INFO | forcefield | sigma=0.5, cutoff=3.0, group=6
# 2025-03-27 12:26:50,580 | INFO | forcefield | Added exclusions from bonded monomers.
# 2025-03-27 12:26:50,581 | INFO | forcefield | HardCoreLJ force successfully added to system.
# 2025-03-27 12:26:50,581 | INFO | forcefield | --------------------------------------------------
# 2025-03-27 12:26:50,582 | INFO | ChromatinDynamics | System set up complete!
# 2025-03-27 12:26:50,582 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:50,582 | INFO | integrators | LangevinIntegrator: temperatute=120.0 | friction=0.1 | timestep=0.01
# 2025-03-27 12:26:50,583 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:50,585 | INFO | ChromatinDynamics | Setting up context...
# 2025-03-27 12:26:50,585 | INFO | ChromatinDynamics | Random position initialization in context
# 2025-03-27 12:26:50,614 | INFO | ChromatinDynamics | Walk completed after 1 attempt(s). Position shape: (1000, 3)
# 2025-03-27 12:26:50,615 | INFO | ChromatinDynamics | Simulation set up complete!
# 2025-03-27 12:26:50,615 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:50,615 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:50,616 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:26:50,616 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:50,617 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.000
# 2025-03-27 12:26:50,622 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.000
# 2025-03-27 12:26:50,622 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:50,623 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 0.000
# 2025-03-27 12:26:50,623 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:26:50,625 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:26:50,625 | INFO | ChromatinDynamics | Running simulation for 10000 steps...
# 2025-03-27 12:27:21,884 | INFO | ChromatinDynamics | Completed 10000 steps in 31.26s (320 steps/s) | Radius of gyration: 21.06
# 2025-03-27 12:27:21,885 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:21,885 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:21,886 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:27:28,041 | INFO | ChromatinDynamics | Completed 2000 steps in 6.15s (325 steps/s) | Radius of gyration: 21.33
# 2025-03-27 12:27:28,042 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:28,043 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:28,044 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:27:28,045 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:28,045 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.585
# 2025-03-27 12:27:28,049 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.017
# 2025-03-27 12:27:28,050 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:28,051 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.538
# 2025-03-27 12:27:28,052 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:28,053 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:28,053 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:27:34,258 | INFO | ChromatinDynamics | Completed 2000 steps in 6.20s (322 steps/s) | Radius of gyration: 21.07
# 2025-03-27 12:27:34,259 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:34,260 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:34,261 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:27:34,262 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:34,263 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.540
# 2025-03-27 12:27:34,267 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.022
# 2025-03-27 12:27:34,267 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:34,268 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.496
# 2025-03-27 12:27:34,269 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:34,270 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:34,271 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:27:40,508 | INFO | ChromatinDynamics | Completed 2000 steps in 6.24s (321 steps/s) | Radius of gyration: 20.92
# 2025-03-27 12:27:40,509 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:40,510 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:40,511 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:27:40,512 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:40,514 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.566
# 2025-03-27 12:27:40,519 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.022
# 2025-03-27 12:27:40,520 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:40,521 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.402
# 2025-03-27 12:27:40,521 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:40,524 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:40,525 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:27:46,740 | INFO | ChromatinDynamics | Completed 2000 steps in 6.21s (322 steps/s) | Radius of gyration: 20.77
# 2025-03-27 12:27:46,742 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:46,742 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:46,743 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:27:46,744 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:46,744 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.543
# 2025-03-27 12:27:46,748 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.023
# 2025-03-27 12:27:46,749 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:46,750 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.497
# 2025-03-27 12:27:46,750 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:46,752 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:46,753 | INFO | ChromatinDynamics | Running simulation for 2000 steps...
# 2025-03-27 12:27:52,922 | INFO | ChromatinDynamics | Completed 2000 steps in 6.17s (324 steps/s) | Radius of gyration: 20.16
# 2025-03-27 12:27:52,924 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-03-27 12:27:52,924 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:52,925 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   Energy/Particle
# 2025-03-27 12:27:52,926 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:52,927 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          999          N/A          0.523
# 2025-03-27 12:27:52,930 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           HardCoreLJ           6        1000         N/A          999          0.021
# 2025-03-27 12:27:52,931 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-03-27 12:27:52,932 | INFO | ChromatinDynamics | Total number of particles: 1000 | Kinetic Energy per particle: 1.513
# 2025-03-27 12:27:52,932 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 21.947325299530554 0.3264913767212485
# 20.85178186061294 0.39128997113413383

# %%
pos = np.array(positions)
pos.shape
# Out:
# (10, 1000, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
n=9
ax.plot(pos[n,:,0], pos[n,:,1], pos[n,:,2])

# %%
for atom in generator.topology.atoms():
    print(atom.element)
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A

# %%
from utilities import Run

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_pos_3Drandom_walk(num_steps, step_size):
    # Generate random directions on the unit sphere
    directions = np.random.normal(size=(num_steps, 3))
    directions /= np.linalg.norm(directions, axis=1)[:, np.newaxis]  # Normalize
    steps = directions * step_size  # Scale to step size
    positions = np.cumsum(steps, axis=0)  # Cumulative sum for path
    return positions  # Shape: (num_steps, 3)

import numpy as np

def self_avoiding_walk_3d(num_steps, step_size, max_retries=1000):
    """
    Generate a 3D self-avoiding walk of given step size.
    Ensures that no two positions are closer than `step_size`.
    """
    positions = [np.zeros(3)]  # start at origin

    for step in range(1, num_steps):
        success = False
        for _ in range(max_retries):
            # Propose a random direction
            direction = np.random.normal(size=3)
            direction /= np.linalg.norm(direction)
            candidate = positions[-1] + step_size * direction

            # Check distance to all previous positions
            dists = np.linalg.norm(np.array(positions) - candidate, axis=1)
            if np.all(dists >= step_size):
                positions.append(candidate)
                success = True
                break

        if not success:
            print(f"Step {step}: Stuck after {max_retries} attempts. Ending walk.")
            break  # Exit early if stuck

    return np.array(positions)

# %%
Rg=[]
for N in [100, 1000, 5000, 10000]:
    pos = self_avoiding_walk_3d(N, 1.0)
    center=np.mean(pos,axis=0)
    Rg.append(np.linalg.norm(np.mean((pos-center)**2, axis=0)))

# %%
plt.loglog([100, 1000, 5000, 10000], Rg,'o--')
plt.loglog([2000,20000], 0.2*np.array([2000,20000])**(1))
