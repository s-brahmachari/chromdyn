# %%
from pathlib import Path
import os
SRC=os.path.join(Path.cwd().parent, 'src')
import sys
sys.path.append(SRC)
from Topology import TopologyGenerator
from ChromatinDynamics import ChromatinDynamics
import openmm.unit as unit
import numpy as np
from LoopExtrusion import Loop_Extruders, Extrusion_kinetics
from Reporters import save_pdb
import h5py

# %%
generator = TopologyGenerator()
generator.gen_top([100])

# %%
for chain in generator.topology.chains():
    print(list(chain.atoms())[0].id, type(list(chain.atoms())[-1].id))
# Out:
# 0 <class 'str'>

# %%
sim3D = ChromatinDynamics(generator.topology, 'LE', output_dir=f'{Path.cwd()}/output', console_stream=True, platform_name="OpenCL")
# Out:
# 2025-04-28 15:44:06,788 | INFO | ChromatinDynamics | ************************************************************
# 2025-04-28 15:44:06,789 | INFO | ChromatinDynamics |                      Chromatin Dynamics
# 2025-04-28 15:44:06,790 | INFO | ChromatinDynamics | ************************************************************
# 2025-04-28 15:44:06,790 | INFO | ChromatinDynamics | Storing output in /Users/sb95/Library/CloudStorage/Box-Box/Research_current/ChromatinDynamics/notebooks/output
# 2025-04-28 15:44:06,791 | INFO | ChromatinDynamics | System initialized with 100 particles.
# 2025-04-28 15:44:06,792 | INFO | Platforms | Platform 'OpenCL' is available and selected.
# 2025-04-28 15:44:06,792 | INFO | ChromatinDynamics | force_field_manager initialized. Use this to add forces to the system before setting up simulation.
# 2025-04-28 15:44:06,793 | INFO | ChromatinDynamics | ------------------------------------------------------------

# %%
sim3D.force_field_manager.add_harmonic_bonds()
# sim.force_field_manager.removeCOM()
sim3D.force_field_manager.add_self_avoidance()
# Out:
# 2025-04-28 15:44:07,689 | INFO | Forcefield | Adding 99 harmonic bonds with parameters:
# 2025-04-28 15:44:07,690 | INFO | Forcefield | length: 1.0, spring constant (k): 10.0, group: 0
# 2025-04-28 15:44:07,691 | INFO | Forcefield | HarmonicBonds force successfully added to system.
# 2025-04-28 15:44:07,691 | INFO | Forcefield | --------------------------------------------------
# 2025-04-28 15:44:07,692 | INFO | Forcefield | Adding Self-avoidance force with parameters:
# 2025-04-28 15:44:07,692 | INFO | Forcefield | Ecut=4.0, k_rep=5.0, r_rep=1.0, cutoff=5.0, group=2
# 2025-04-28 15:44:07,693 | INFO | Forcefield | Added exclusions from bonded monomers.
# 2025-04-28 15:44:07,693 | INFO | Forcefield | SelfAvoidance force successfully added to system.
# 2025-04-28 15:44:07,693 | INFO | Forcefield | --------------------------------------------------

# %%
sim3D.simulation_setup(init_struct='randomwalk',save_pos=True, save_energy=True)
# Out:
# 2025-04-28 15:44:08,558 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-04-28 15:44:08,560 | INFO | Integrators | Valid integrators: ['langevin', 'brownian', 'active-brownian']| Selected: langevin
# 2025-04-28 15:44:08,561 | INFO | Integrators | LangevinIntegrator: temperatute=120.0 | friction=0.1 | timestep=0.01
# 2025-04-28 15:44:08,653 | INFO | ChromatinDynamics | Setting up context...
# 2025-04-28 15:44:08,654 | INFO | Utilities | Random walk created. Position shape: (100, 3)
# 2025-04-28 15:44:08,656 | INFO | ChromatinDynamics | Simulation set up complete!
# 2025-04-28 15:44:08,656 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-04-28 15:44:08,657 | INFO | ChromatinDynamics | Index  Force Class                    Force Name           Group    Particles    Bonds        Exclusions   P.E./Particle
# 2025-04-28 15:44:08,657 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-04-28 15:44:08,662 | INFO | ChromatinDynamics | 0      HarmonicBondForce              HarmonicBonds        0        N/A          99           N/A          0.000
# 2025-04-28 15:44:08,670 | INFO | ChromatinDynamics | 1      CustomNonbondedForce           SelfAvoidance        2        100          N/A          99           6.219
# 2025-04-28 15:44:08,674 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-04-28 15:44:08,675 | INFO | ChromatinDynamics | Total number of particles: 100 | K.E. per particle: 0.005 | P.E. per particle: 6.219
# 2025-04-28 15:44:08,675 | INFO | ChromatinDynamics | ------------------------------------------------------------------------------------------------------------------------
# 2025-04-28 15:44:08,676 | INFO | Reporters | StabilityReporter initialized with thresholds: K.E. = 100000.0, P.E. = 100000.0
# 2025-04-28 15:44:08,677 | INFO | ChromatinDynamics | Creating Instability report at /Users/sb95/Library/CloudStorage/Box-Box/Research_current/ChromatinDynamics/notebooks/output/LE_stability_report.txt.
# 2025-04-28 15:44:08,677 | INFO | ChromatinDynamics | Created Energy reporter at /Users/sb95/Library/CloudStorage/Box-Box/Research_current/ChromatinDynamics/notebooks/output/LE_energy_report.txt.
# 2025-04-28 15:44:08,678 | INFO | ChromatinDynamics | Created Position reporter at /Users/sb95/Library/CloudStorage/Box-Box/Research_current/ChromatinDynamics/notebooks/output/LE_positions.cndb.

# %%
sim3D.run(1000)
# Out:
# 2025-04-28 15:44:10,228 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 2025-04-28 15:44:10,229 | INFO | ChromatinDynamics | Running simulation for 1000 steps...
# 2025-04-28 15:44:10,356 | INFO | ChromatinDynamics | Completed 1000 steps in 0.13s (7917 steps/s)
# 2025-04-28 15:44:10,356 | INFO | ChromatinDynamics | ------------------------------------------------------------
# 7917.022630020216

# %%
sim3D.force_field_manager.removeForce(sim3D.simulation.context,'HarmonicBonds')
# Out:
# 2025-04-28 15:45:47,683 | INFO | Forcefield | Removed HarmonicBonds from the system!

# %%
lef = Loop_Extruders(name='smc',num_LE=1, chain_topology=generator.topology,
                     k_off=0.01, k_hop=0.1, kstep_LE=1.0, stepsize_LE=3.0,
                     sim3D=sim3D, tau=1e2)
print("3D hopping", lef.hop3D)
print("Preferential loading", lef.preferential_LE_loading)
print("Temperature", lef.temp)
# lef.update_immobile_blockers(boundaries)
lef.unbind_at_end = True
# Out:
# Random seed 36394945
# Randomly distributing the LEFs
# 3D hopping False
# Preferential loading 0.0
# Temperature 0.0

# %%
sim1D = Extrusion_kinetics(lef)
# Out:
# Initialized extrusion kinetics with the random seed  32812

# %%
def closest_lower_index(t, A):
    return max((i for i, x in enumerate(A) if x <= t), key=lambda i: A[i], default=None)

def add_new_LEFBonds(sim1D, sim3D, nsteps):
    anchor_locs = []
    activation_times = []
    leids = []
    for time_val in sorted(sim1D.lef.anchor_loc_dict.keys())[-nsteps-1:]:
        
        anchor_locs.append(sim1D.lef.anchor_loc_dict[time_val][0])
        activation_times.append(time_val)
        leids.append(sim1D.lef.anchor_loc_dict[time_val][1])
        # print(time_val,sim1D.lef.anchor_loc_dict[time_val] ,"yosemite")
    
    anchor_locs = np.array(anchor_locs, dtype=int)
    leids = np.array(leids, dtype=str)
    unique_anchor_locs = list(map(list, set(map(tuple, anchor_locs.reshape(-1,2)))))
    
    sim3D.force_field_manager.removeForce("LEFBonds")
    sim3D.force_field_manager.addLEFBonds(anchors=unique_anchor_locs)
    
    # print(f"Total LEF bonds added: {sim3D.forceDict['LEFBond'].getNumBonds()}")
    # for bid in range(sim3D.forceDict["LEFBond"].getNumBonds()):
    #     params=sim3D.forceDict['LEFBond'].getBondParameters(bid)
    #     print('bond params', params)
    
    return anchor_locs, activation_times, leids
        
def activate_LEFBonds(sim3D, activated_anchors,kLE):
    
    num_LEFBonds = sim3D.forceDict["LEFBond"].getNumBonds()
    for bond_id in range(num_LEFBonds):
        particle1, particle2, _ = sim3D.forceDict['LEFBond'].getBondParameters(bond_id)
        k_LE_bond = 0.0
        for anchor1, anchor2 in activated_anchors:
            
            if anchor1==particle1 and anchor2==particle2: 
                # print('grand canyon', anchor1, anchor2, particle1, particle2)
                k_LE_bond = kLE
                
        sim3D.forceDict['LEFBond'].setBondParameters(bond_id, particle1, particle2, 1.0, k_LE_bond)
    sim3D.forceDict['LEFBond'].updateParametersInContext(sim3D.context)

def run_sim(sim3D, sim1D, lef, tstop, update_interval=10.0, verbose=False):

    anchor_loc_dict = {}
    
    resisting_force = []
    active_force = [[],[]]
    # matching time scales
    t1D_unit = 1 # second
    t3D_unit = 0.1 # second
    dt=0.01 # t3D
    blocksize = 500
    tblock = blocksize*dt*t3D_unit # second

    time3D = 0
    update_lag = 10 #num events before updating 3D sims
    update_lag_time = update_interval

    # temper_polymer(sim3D, blocksize=5000, dT=50.0)
    
    num_events_since_last_3D_update = 0
    time_since_last_3D_update = 0.0

    while time3D<tstop:
        sim1D.simulate(verbose=verbose)    
        num_events_since_last_3D_update += 1
        time_since_last_3D_update += sim1D.dt
        
        if time_since_last_3D_update // update_lag_time > 0.0:
        # if num_events_since_last_3D_update % update_lag == 0 and time3D<sim1D.time:
            print("\nUpdate 3D sims ...")
            anchor_locations, activation_times, leids = add_new_LEFBonds(sim1D, sim3D, num_events_since_last_3D_update)
            
            assert anchor_locations.shape[0]==num_events_since_last_3D_update+1, f'shape mismatch!! {anchor_locations.shape,num_events_since_last_3D_update}'
                            
            activated_index = 0
            activate_LEFBonds(sim3D, anchor_locations[activated_index],kLE=lef.k_LE)
            # print(anchor_locations.shape)
            #output the anchors
            # lef.output_anchor_locations(output)
            lef.reset_LE_resisting_forces()
            
            for time_stamp in np.arange(time3D, sim1D.time, tblock):
                
                index_to_be_activated = closest_lower_index(time_stamp, activation_times)
                if index_to_be_activated is not None and index_to_be_activated != activated_index:
                    # if new_bonds_needed(anchor_locations[index_to_be_activated], anchor_locations[activated_index]):
                    if not np.array_equal(anchor_locations[index_to_be_activated], anchor_locations[activated_index]):
                        activate_LEFBonds(sim3D, anchor_locations[index_to_be_activated],kLE=lef.k_LE)
                        print(f" --> Activated 1D time point: {activation_times[index_to_be_activated]:<8.5f} | Current 3D time:{time3D:<8.5f}")
                        # print(anchor_locations[index_to_be_activated])
                    activated_index = index_to_be_activated
                    
                try:
                    sim3D.run(blocksize, report=True)
                    # sim3D.printForces()
                    # sim3D.saveStructure()
                    lef.update_LE_resisting_force(leids[activated_index], anchor_locations[activated_index])
                    
                    anchor_loc_dict[time_stamp] = anchor_locations[activated_index]
                    coords = sim3D.state.getPositions(asNumpy=True)
                    resisting_force.append(sim1D.lef.loop_extruder_dict["LE_0"]['resisting_force'])
                    active_force[0].append(sim1D.lef.loop_extruder_dict["LE_0"]['active_force_left'])
                    active_force[1].append(sim1D.lef.loop_extruder_dict["LE_0"]['active_force_right'])
                    
                    # print(time3D, sim1D.time, time_stamp, anchor_locations[activated_index])
                    le_bond_distance=np.linalg.norm(coords[anchor_locations[activated_index][0][0]]-coords[anchor_locations[activated_index][0][1]])
                    # print(coords.shape, anchor_locations[activated_index])
                    print(f'LE_bond--{le_bond_distance}', anchor_locations[activated_index][0][0], anchor_locations[activated_index][0][1])
                except ():
                    sim3D.print_force_info()
                time3D += tblock
                
            num_events_since_last_3D_update = 0
            time_since_last_3D_update = 0.0
            # lef.update_LE_resisting_forces()
            print("\nRun 1D sims ...")

# %%
run_sim(sim3D, sim1D, lef, tstop=1e3, update_interval=100.0, verbose=1)
# Out:
# 2025-04-28 15:29:12,035 | WARNING | Forcefield | The system does not have force LEFBonds!!
# 2025-04-28 15:29:12,036 | WARNING | Forcefield | The forces applied in the system are: dict_keys(['HarmonicBonds', 'SelfAvoidance'])
# traverse_LE: dx=2.1389697714804115 | force=4.868142630954384 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.43361147410498574, t_mesh=0.001
# 78 81.13896977148042
# Time: 0.433611   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 2
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 78.00, 81.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 78.00, 79.00) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.0107576249761143 | force=5.408959133710566 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.19207027758033043, t_mesh=0.001
# 78 82.14972739645653
# Time: 0.625682   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 78.00, 82.15) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 78.00, 81.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=5.634569582742136 | force=5.6000496057519715 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=1.0306213530786363, t_mesh=0.001
# 78 87.78429697919866
# Time: 1.656303   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 6
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 78.00, 87.78) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 78.00, 82.15) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.5547056731108324 | force=5.721513325929586 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.28833770832832556, t_mesh=0.001
# 78 89.33900265230949
# Time: 1.944641   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 2
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 78.00, 89.34) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 78.00, 87.78) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.11551691865393973 | force=5.777840711944143 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.020295775651546655, t_mesh=0.001
# 78 89.45451957096343
# Time: 1.964937   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 78.00, 89.45) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 78.00, 89.34) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.201046268755981 | force=3.929469021868261 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6757251651148993, t_mesh=0.001
# 74.79895373124401 89.45451957096343
# Time: 2.640662   |    LE_0    move_left_anchor     | dx_left: -3     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 74.80, 89.45) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 78.00, 89.45) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.7060443102582469 | force=3.7824924858017233 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.18063285052697658, t_mesh=0.001
# 74.09290942098576 89.45451957096343
# Time: 2.821295   |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 74.09, 89.45) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 74.80, 89.45) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.0890872084168073 | force=4.156363575614005 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.28089220755811334, t_mesh=0.001
# 73.00382221256895 89.45451957096343
# Time: 3.102187   |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 73.00, 89.45) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 74.09, 89.45) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.02875173652238905 | force=5.751215931105701 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.005902077640876242, t_mesh=0.001
# 73.00382221256895 89.48327130748582
# Time: 3.108089   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 73.00, 89.48) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 73.00, 89.45) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.606833279022914 | force=5.849360844350163 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.1061074198854123, t_mesh=0.001
# 73.00382221256895 90.09010458650873
# Time: 3.214196   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 73.00, 90.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 73.00, 89.48) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.9707092813108776 | force=4.373500615260585 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.22210463077884285, t_mesh=0.001
# 72.03311293125807 90.09010458650873
# Time: 3.436301   |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 72.03, 90.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 73.00, 90.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=7.2952787568340876 | force=6.1092877439476 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=1.2356030735966903, t_mesh=0.001
# 72.03311293125807 97.38538334334282
# Time: 4.671904   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 7
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 72.03, 97.39) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 72.03, 90.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.741821663471677 | force=4.276614490098957 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.9018822218617386, t_mesh=0.001
# 68.29129126778639 97.38538334334282
# Time: 5.573786   |    LE_0    move_left_anchor     | dx_left: -4     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 68.29, 97.39) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 72.03, 97.39) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.158012925796099 | force=6.074114854432489 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.3489238866141145, t_mesh=0.001
# 68.29129126778639 98.38538334334282
# Time: 5.922710   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 68.29, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 68.29, 97.39) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.038497122082154465 | force=4.222568911385093 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.009999545770648795, t_mesh=0.001
# 68.25279414570424 98.38538334334282
# Time: 5.932710   |    LE_0    move_left_anchor     | dx_left: -0     | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 68.25, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 68.29, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=0.23268265575248842 | force=4.112978470042595 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.056176086770170615, t_mesh=0.001
# 68.02011148995176 98.38538334334282
# Time: 5.988886   |    LE_0    move_left_anchor     | dx_left: -0     | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 68.02, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 68.25, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=3.0029918490454346 | force=5.896200787094815 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.4909825190535907, t_mesh=0.001
# 68.02011148995176 98.38538334334282
# Time: 6.479868   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Zero loop state!
# LE_0    currently anchored at  ( 68.02, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 68.02, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=7.261410598572234 | force=5.264630097526505 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=1.2185555061407145, t_mesh=0.001
# 68.02011148995176 98.38538334334282
# Time: 7.698424   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Zero loop state!
# LE_0    currently anchored at  ( 68.02, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 68.02, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=0.026391117641351748 | force=5.29145693835467 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.005038993018154321, t_mesh=0.001
# 68.02011148995176 98.41177446098418
# Time: 7.703463   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 68.02, 98.41) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 68.02, 98.39) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=0.19093014688666626 | force=5.306000584284849 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.036075938784087005, t_mesh=0.001
# 68.02011148995176 98.60270460787085
# Time: 7.739539   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 68.02, 98.60) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 68.02, 98.41) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=3.0810037915113657 | force=5.241110912111468 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5859173833788325, t_mesh=0.001
# 68.02011148995176 98.60270460787085
# Time: 8.325456   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Zero loop state!
# LE_0    currently anchored at  ( 68.02, 98.60) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 68.02, 98.60) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# 87 88
# Time: 8.493791   |    LE_0    unbind               | dx_left: 19     | dx_right: -11
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Un/rebinding
# LE_0    currently anchored at  ( 87.00, 88.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at ( 68.02, 98.60) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=0.11162961957587215 | force=4.7068421868199435 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.023730562070287495, t_mesh=0.001
# 87 88.11162961957588
# Time: 8.517521   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 87.00, 88.11) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at ( 87.00, 88.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=0.5254404114965883 | force=4.665173478792276 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.111283383288776, t_mesh=0.001
# 87 88.63707003107247
# Time: 8.628805   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 87.00, 88.64) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at ( 87.00, 88.11) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=0.5810272824161434 | force=5.258446660142589 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.11245818181417651, t_mesh=0.001
# 86.41897271758386 88.63707003107247
# Time: 8.741263   |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 86.42, 88.64) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 87.00, 88.64) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=2.573347633200194 | force=4.9216082413449485 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5514337755499858, t_mesh=0.001
# 86.41897271758386 91.21041766427267
# Time: 9.292697   |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 86.42, 91.21) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 86.42, 88.64) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.217012588767896 | force=5.512378122344061 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.22309251302243188, t_mesh=0.001
# 85.20196012881595 91.21041766427267
# Time: 9.515789   |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 85.20, 91.21) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 86.42, 91.21) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.278715978794023 | force=5.617130681987986 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5674319986386892, t_mesh=0.001
# 81.92324415002193 91.21041766427267
# Time: 10.083221  |    LE_0    move_left_anchor     | dx_left: -3     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 81.92, 91.21) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 85.20, 91.21) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.35686278176475433 | force=5.2041546900163125 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.07088325486139026, t_mesh=0.001
# 81.92324415002193 91.56728044603743
# Time: 10.154104  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 81.92, 91.57) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 81.92, 91.21) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.1662120462244847 | force=4.749219653770944 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.24051186811330502, t_mesh=0.001
# 81.92324415002193 92.73349249226192
# Time: 10.394616  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 81.92, 92.73) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 81.92, 91.57) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.23283382903442937 | force=5.438404614516585 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.04257479497715799, t_mesh=0.001
# 81.6904103209875 92.73349249226192
# Time: 10.437191  |    LE_0    move_left_anchor     | dx_left: -0     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 81.69, 92.73) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 81.92, 92.73) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=5.007197190982616 | force=4.565103342684834 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=1.0788824144672704, t_mesh=0.001
# 81.6904103209875 97.74068968324454
# Time: 11.516073  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 5
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 81.69, 97.74) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 81.69, 92.73) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.804514029974405 | force=4.889166773825509 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.39771514415523096, t_mesh=0.001
# 81.6904103209875 98.74068968324454
# Time: 11.913789  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 81.69, 98.74) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 81.69, 97.74) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.3069959248347403 | force=4.887958606021167 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.06302143453853119, t_mesh=0.001
# 81.6904103209875 98.74068968324454
# Time: 11.976810  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Zero loop state!
# LE_0    currently anchored at  ( 81.69, 98.74) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 81.69, 98.74) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# 68 69
# Time: 12.608633  |    LE_0    unbind               | dx_left: -14    | dx_right: -30
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Un/rebinding
# LE_0    currently anchored at  ( 68.00, 69.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at ( 81.69, 98.74) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=0.45772973967842734 | force=4.921851139709479 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.09102840205244254, t_mesh=0.001
# 68 69.45772973967843
# Time: 12.699662  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 68.00, 69.46) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at ( 68.00, 69.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=0.28907154345268876 | force=4.880241561480447 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.05838117819908789, t_mesh=0.001
# 68 69.74680128313112
# Time: 12.758043  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 68.00, 69.75) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at ( 68.00, 69.46) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=0.8529379169896695 | force=5.2601337658062555 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.16110168494711857, t_mesh=0.001
# 67.14706208301033 69.74680128313112
# Time: 12.919145  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 67.15, 69.75) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 68.00, 69.75) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=3.9354436078780672 | force=5.746794105113542 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.7398753077271908, t_mesh=0.001
# 67.14706208301033 73.68224489100919
# Time: 13.659020  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 4
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 67.15, 73.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 67.15, 69.75) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.4626101092910337 | force=5.157043062484536 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6441035293218311, t_mesh=0.001
# 63.68445197371929 73.68224489100919
# Time: 14.303123  |    LE_0    move_left_anchor     | dx_left: -3     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 63.68, 73.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 67.15, 73.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=5.522136804582998 | force=4.966640036785191 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=1.1534798371302117, t_mesh=0.001
# 58.16231516913629 73.68224489100919
# Time: 15.456603  |    LE_0    move_left_anchor     | dx_left: -6     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 58.16, 73.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 63.68, 73.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.9714190050965112 | force=4.625556379898041 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.4064311243760585, t_mesh=0.001
# 56.19089616403978 73.68224489100919
# Time: 15.863034  |    LE_0    move_left_anchor     | dx_left: -2     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 56.19, 73.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 58.16, 73.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.5154751621879519 | force=5.801935562968291 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.0890362793984223, t_mesh=0.001
# 56.19089616403978 74.19772005319714
# Time: 15.952071  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 56.19, 74.20) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 56.19, 73.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.24900252502005005 | force=4.627893266553198 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.05475459357351687, t_mesh=0.001
# 55.941893639019725 74.19772005319714
# Time: 16.006825  |    LE_0    move_left_anchor     | dx_left: -0     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 55.94, 74.20) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 56.19, 74.20) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.27442020913765847 | force=5.924384495644081 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.04747047026218607, t_mesh=0.001
# 55.941893639019725 74.4721402623348
# Time: 16.054296  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 55.94, 74.47) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 55.94, 74.20) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.1955204064819993 | force=5.57273285100115 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.370749144550475, t_mesh=0.001
# 55.941893639019725 76.66766066881681
# Time: 16.425045  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 2
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 55.94, 76.67) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 55.94, 74.47) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.18167724398327612 | force=5.797395883297389 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.032696934774097304, t_mesh=0.001
# 55.941893639019725 76.84933791280008
# Time: 16.457742  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 55.94, 76.85) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 55.94, 76.67) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.294301293938342 | force=6.090612048612773 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.2228089009980812, t_mesh=0.001
# 55.941893639019725 78.14363920673843
# Time: 16.680551  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 55.94, 78.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 55.94, 76.85) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.5760852958423457 | force=4.6207660000459425 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.7675610322399581, t_mesh=0.001
# 52.36580834317738 78.14363920673843
# Time: 17.448112  |    LE_0    move_left_anchor     | dx_left: -4     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 52.37, 78.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 55.94, 78.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=4.404219488225179 | force=4.763642379083889 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.9200649936592702, t_mesh=0.001
# 47.9615888549522 78.14363920673843
# Time: 18.368177  |    LE_0    move_left_anchor     | dx_left: -4     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 47.96, 78.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 52.37, 78.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.056723811349752 | force=4.183432974394782 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.682452905620042, t_mesh=0.001
# 44.90486504360244 78.14363920673843
# Time: 19.050630  |    LE_0    move_left_anchor     | dx_left: -3     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 44.90, 78.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 47.96, 78.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=5.6857570366262795 | force=6.319877244062721 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.929536910629656, t_mesh=0.001
# 44.90486504360244 83.82939624336471
# Time: 19.980166  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 6
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 44.90, 83.83) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 44.90, 78.14) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=7.175363760385964 | force=6.312936368238283 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=1.1440423122180705, t_mesh=0.001
# 44.90486504360244 91.00476000375068
# Time: 21.124209  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 7
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 44.90, 91.00) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 44.90, 83.83) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=5.198163860607764 | force=6.15710158408784 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.8176271640481951, t_mesh=0.001
# 44.90486504360244 96.20292386435844
# Time: 21.941836  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 5
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 44.90, 96.20) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 44.90, 91.00) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.5739092402448502 | force=6.125407299827595 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.2504759704493187, t_mesh=0.001
# 44.90486504360244 97.77683310460328
# Time: 22.192312  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 2
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 44.90, 97.78) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 44.90, 96.20) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.7152574500790692 | force=3.8381247757215204 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.4311979314745275, t_mesh=0.001
# 43.18960759352337 97.77683310460328
# Time: 22.623510  |    LE_0    move_left_anchor     | dx_left: -2     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 43.19, 97.78) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 44.90, 97.78) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.065228398603558 | force=4.227222901944251 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5384125292464182, t_mesh=0.001
# 41.12437919491981 97.77683310460328
# Time: 23.161922  |    LE_0    move_left_anchor     | dx_left: -2     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 41.12, 97.78) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 43.19, 97.78) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=8.483144359867799 | force=6.9887768995943125 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=1.3022018488087752, t_mesh=0.001
# 41.12437919491981 98.77683310460328
# Time: 24.464124  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 41.12, 98.78) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 41.12, 97.78) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.24006509773572096 | force=6.804849399752265 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.0359077796193392, t_mesh=0.001
# 41.12437919491981 98.77683310460328
# Time: 24.500032  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Zero loop state!
# LE_0    currently anchored at  ( 41.12, 98.78) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
# LE_0    previously anchored at ( 41.12, 98.78) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# 47 48
# Time: 24.801703  |    LE_0    unbind               | dx_left: 6      | dx_right: -51
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Un/rebinding
# LE_0    currently anchored at  ( 47.00, 48.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at ( 41.12, 98.78) | left blocked by (None   ,None   ) | right blocked by (None   ,End    )
#
#
# traverse_LE: dx=3.087244349205505 | force=4.115617803798289 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6728681100257294, t_mesh=0.001
# 47 51.087244349205506
# Time: 25.474571  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 47.00, 51.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 47.00, 48.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=2.1957149733748618 | force=5.151615828438145 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.43637163047264943, t_mesh=0.001
# 44.80428502662514 51.087244349205506
# Time: 25.910943  |    LE_0    move_left_anchor     | dx_left: -2     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 44.80, 51.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 47.00, 51.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.9344955863148555 | force=4.6498687443375175 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.19542433551136948, t_mesh=0.001
# 43.869789440310285 51.087244349205506
# Time: 26.106367  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 43.87, 51.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 44.80, 51.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.6480564357066436 | force=4.283000879926314 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6371127525674094, t_mesh=0.001
# 43.869789440310285 53.73530078491215
# Time: 26.743480  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 43.87, 53.74) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 43.87, 51.09) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.3266544036490644 | force=5.175629954902021 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6833902368590296, t_mesh=0.001
# 40.54313503666122 53.73530078491215
# Time: 27.426870  |    LE_0    move_left_anchor     | dx_left: -3     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 40.54, 53.74) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 43.87, 53.74) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.363491444352253 | force=4.629742306112165 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.3073865551740778, t_mesh=0.001
# 40.54313503666122 55.098792229264404
# Time: 27.734256  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 40.54, 55.10) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 40.54, 53.74) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.204930233437854 | force=5.00766526977314 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.4610609206754349, t_mesh=0.001
# 40.54313503666122 57.30372246270226
# Time: 28.195317  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 2
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 40.54, 57.30) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 40.54, 55.10) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.5353704102386595 | force=5.196773845289398 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.1044172447682228, t_mesh=0.001
# 40.54313503666122 57.839092872940924
# Time: 28.299735  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 40.54, 57.84) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 40.54, 57.30) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.983703981499026 | force=5.378726489149835 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.1855840149982816, t_mesh=0.001
# 39.55943105516219 57.839092872940924
# Time: 28.485319  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 39.56, 57.84) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 40.54, 57.84) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.41587331736799654 | force=5.4829271104734705 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.07631395357822134, t_mesh=0.001
# 39.1435577377942 57.839092872940924
# Time: 28.561633  |    LE_0    move_left_anchor     | dx_left: -0     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 39.14, 57.84) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 39.56, 57.84) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.2190249233989734 | force=4.731284643972834 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6490798526402115, t_mesh=0.001
# 39.1435577377942 61.0581177963399
# Time: 29.210712  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 39.14, 61.06) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 39.14, 57.84) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.538210766265279 | force=5.638874655993889 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.09641768990250085, t_mesh=0.001
# 38.60534697152892 61.0581177963399
# Time: 29.307130  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 38.61, 61.06) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 39.14, 61.06) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.840469162061237 | force=5.072396353356331 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5859996918208923, t_mesh=0.001
# 38.60534697152892 63.89858695840114
# Time: 29.893130  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 38.61, 63.90) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 38.61, 61.06) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.586202402771805 | force=5.398664276444372 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.10584485318615088, t_mesh=0.001
# 38.01914456875711 63.89858695840114
# Time: 29.998975  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 38.02, 63.90) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 38.61, 63.90) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.274496514893819 | force=5.099612666656609 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.2392339132943461, t_mesh=0.001
# 36.744648053863294 63.89858695840114
# Time: 30.238209  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 36.74, 63.90) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 38.02, 63.90) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.2893919268842424 | force=4.5963840617572815 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6714769454026349, t_mesh=0.001
# 36.744648053863294 67.18797888528539
# Time: 30.909686  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 36.74, 67.19) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 36.74, 63.90) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.893562402028801 | force=4.458516000249268 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.19731067849369965, t_mesh=0.001
# 36.744648053863294 68.0815412873142
# Time: 31.106996  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 36.74, 68.08) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 36.74, 67.19) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.9289254628468895 | force=4.9970780433018485 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.38321665625019874, t_mesh=0.001
# 34.8157225910164 68.0815412873142
# Time: 31.490213  |    LE_0    move_left_anchor     | dx_left: -2     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 34.82, 68.08) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 36.74, 68.08) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.2215519365732021 | force=4.370275331590996 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.05174172041750755, t_mesh=0.001
# 34.8157225910164 68.3030932238874
# Time: 31.541955  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 34.82, 68.30) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 34.82, 68.08) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.6253345692050325 | force=5.127648275029756 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5704301633792521, t_mesh=0.001
# 34.8157225910164 70.92842779309244
# Time: 32.112385  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 34.82, 70.93) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 34.82, 68.30) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=4.7704322233189975 | force=5.5445289205641775 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.8771864678282745, t_mesh=0.001
# 34.8157225910164 75.69886001641143
# Time: 32.989571  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 5
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 34.82, 75.70) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 34.82, 70.93) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.840198312630739 | force=4.926979841640548 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5384400627719935, t_mesh=0.001
# 34.8157225910164 78.53905832904216
# Time: 33.528011  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 34.82, 78.54) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 34.82, 75.70) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.6641046905434114 | force=6.014226475114805 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5122468779691237, t_mesh=0.001
# 34.8157225910164 81.20316301958557
# Time: 34.040258  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 34.82, 81.20) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 34.82, 78.54) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.979004987709279 | force=4.916495713783781 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5544150929085138, t_mesh=0.001
# 34.8157225910164 84.18216800729485
# Time: 34.594673  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  ( 34.82, 84.18) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 34.82, 81.20) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.9365134461038093 | force=4.665305739687554 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.19556135436701888, t_mesh=0.001
# 33.87920914491259 84.18216800729485
# Time: 34.790235  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 33.88, 84.18) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 34.82, 84.18) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.9486251977140039 | force=4.914196430220452 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.19691502627796978, t_mesh=0.001
# 33.87920914491259 85.13079320500886
# ...
# Time: 83.914114  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  (  2.86, 85.11) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  3.96, 85.11) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.24274168715633257 | force=1.7862527268828574 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.13569901620440974, t_mesh=0.001
# 2.615523814762189 85.11372000595445
# Time: 84.049813  |    LE_0    move_left_anchor     | dx_left: -0     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  (  2.62, 85.11) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.86, 85.11) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=4.623462719114631 | force=2.388520925766858 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=2.2020513988318586, t_mesh=0.001
# 1.6155238147621889 85.11372000595445
# Time: 86.251865  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  (  1.62, 85.11) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.62, 85.11) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.7591497671812215 | force=3.42724698668235 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6081939667558278, t_mesh=0.001
# 1.6155238147621889 85.11372000595445
# Time: 86.860059  |    LE_0    move_left_anchor     | dx_left: 0      | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Zero loop state!
# LE_0    currently anchored at  (  1.62, 85.11) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  1.62, 85.11) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
#
#
# 8 9
# Time: 87.178956  |    LE_0    unbind               | dx_left: 6      | dx_right: -76
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Un/rebinding
# LE_0    currently anchored at  (  8.00,  9.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at (  1.62, 85.11) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=6.022579192124239 | force=3.8174809478763154 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=1.386926950746559, t_mesh=0.001
# 8 15.022579192124239
# Time: 88.565883  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 6
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  8.00, 15.02) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  8.00,  9.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=1.4495079471459484 | force=3.3525922753851485 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.3859645845799325, t_mesh=0.001
# 8 16.472087139270187
# Time: 88.951847  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  8.00, 16.47) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  8.00, 15.02) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.3175814604580588 | force=5.130824268526072 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.06260428042711204, t_mesh=0.001
# 7.682418539541941 16.472087139270187
# Time: 89.014452  |    LE_0    move_left_anchor     | dx_left: -0     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  (  7.68, 16.47) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  8.00, 16.47) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.6975629092450589 | force=5.013635129988102 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.13800945880125104, t_mesh=0.001
# 6.984855630296882 16.472087139270187
# Time: 89.152461  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  (  6.98, 16.47) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  7.68, 16.47) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.96206442947276 | force=3.360231139032281 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5521432127317937, t_mesh=0.001
# 6.984855630296882 18.434151568742948
# Time: 89.704604  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 2
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  6.98, 18.43) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  6.98, 16.47) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=6.3622358420275145 | force=3.5002985169028205 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=2.0068017316277365, t_mesh=0.001
# 6.984855630296882 24.796387410770464
# Time: 91.711406  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 6
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  6.98, 24.80) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  6.98, 18.43) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.420972911522521 | force=4.962291695652098 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6664818042038965, t_mesh=0.001
# 3.563882718774361 24.796387410770464
# Time: 92.377888  |    LE_0    move_left_anchor     | dx_left: -3     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  (  3.56, 24.80) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  6.98, 24.80) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.406502258451358 | force=4.873414720184026 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.28701360954847366, t_mesh=0.001
# 2.1573804603230027 24.796387410770464
# Time: 92.664902  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  (  2.16, 24.80) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  3.56, 24.80) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.0616540259432705 | force=3.4844003614404864 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5989814512990308, t_mesh=0.001
# 2.1573804603230027 26.858041436713734
# Time: 93.263883  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 2
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  2.16, 26.86) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.16, 24.80) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=9.199311811815933 | force=3.6821833286173105 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=2.7089896969708716, t_mesh=0.001
# 2.1573804603230027 36.057353248529665
# Time: 95.972873  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 9
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  2.16, 36.06) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.16, 26.86) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.5324854396937903 | force=3.52724857547904 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.14463032456359623, t_mesh=0.001
# 2.1573804603230027 36.58983868822346
# Time: 96.117503  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 1
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  2.16, 36.59) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.16, 36.06) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.093807398440047 | force=4.197753397519812 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.7798418298669675, t_mesh=0.001
# 2.1573804603230027 39.68364608666351
# Time: 96.897345  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  2.16, 39.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.16, 36.59) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.05089980230716157 | force=4.238442654425056 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.012225690643612994, t_mesh=0.001
# 2.1573804603230027 39.73454588897067
# Time: 96.909570  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  2.16, 39.73) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.16, 39.68) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=1.7498192095010516 | force=5.391023333607938 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.3753198084298168, t_mesh=0.001
# 2.1573804603230027 41.48436509847173
# Time: 97.284890  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 2
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped right
# LE_0    currently anchored at  (  2.16, 41.48) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.16, 39.73) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.8708873821823704 | force=4.451756473554941 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.18720925274181832, t_mesh=0.001
# 1.2864930781406323 41.48436509847173
# Time: 97.472100  |    LE_0    move_left_anchor     | dx_left: -1     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  (  1.29, 41.48) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  2.16, 41.48) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=4.083786587665194 | force=5.751472507820519 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6832531751483333, t_mesh=0.001
# 1.2864930781406323 45.56815168613692
# Time: 98.155353  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 4
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Stepped right
# LE_0    currently anchored at  (  1.29, 45.57) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  1.29, 41.48) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=2.9716001077547047 | force=5.695613506088857 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.5266190409850153, t_mesh=0.001
# 1.2864930781406323 48.539751793891625
# Time: 98.681972  |    LE_0    move_right_anchor    | dx_left: 0      | dx_right: 3
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Stepped right
# LE_0    currently anchored at  (  1.29, 48.54) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  1.29, 45.57) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=0.002180627476559468 | force=4.449374443013603 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.0006109710928629033, t_mesh=0.00012219421857258066
# 1.2843124506640728 48.539751793891625
# Time: 98.682583  |    LE_0    move_left_anchor     | dx_left: -0     | dx_right: 0
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Stepped left
# LE_0    currently anchored at  (  1.28, 48.54) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at (  1.29, 48.54) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
#
#
# 17 18
# Time: 99.009490  |    LE_0    unbind               | dx_left: 16     | dx_right: -31
# Rate vector: [1. 1. 1. 0. 0.]
# LE_0 Un/rebinding
# LE_0    currently anchored at  ( 17.00, 18.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
# LE_0    previously anchored at (  1.28, 48.54) | left blocked by (End    ,None   ) | right blocked by (None   ,None   )
#
#
# traverse_LE: dx=3.3546158638379526 | force=5.4410821424150875 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.6387982981798667, t_mesh=0.001
# 13.645384136162047 18
# Time: 99.648288  |    LE_0    move_left_anchor     | dx_left: -3     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 13.65, 18.00) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 17.00, 18.00) | left blocked by (None   ,LE_0   ) | right blocked by (LE_0   ,None   )
#
#
# traverse_LE: dx=2.4085786108514253 | force=5.509027976827541 | fres=(0.0, 0.0) | cutoff=0.9999546021312975, dt=0.43761276611513317, t_mesh=0.001
# 11.236805525310622 18
# Time: 100.085901 |    LE_0    move_left_anchor     | dx_left: -2     | dx_right: 0
# Rate vector: [0.01 1.   1.   0.   0.  ]
# LE_0 Stepped left
# LE_0    currently anchored at  ( 11.24, 18.00) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
# LE_0    previously anchored at ( 13.65, 18.00) | left blocked by (None   ,None   ) | right blocked by (None   ,None   )
#
#
#
# Update 3D sims ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 run_sim(sim3D, sim1D, lef, tstop=1e3, update_interval=100.0, verbose=1)
#
# Cell In[9], line 74, in run_sim(sim3D, sim1D, lef, tstop, update_interval, verbose)
#      71 if time_since_last_3D_update // update_lag_time > 0.0:
#      72 # if num_events_since_last_3D_update % update_lag == 0 and time3D<sim1D.time:
#      73     print("\nUpdate 3D sims ...")
# ---> 74     anchor_locations, activation_times, leids = add_new_LEFBonds(sim1D, sim3D, num_events_since_last_3D_update)
#      76     assert anchor_locations.shape[0]==num_events_since_last_3D_update+1, f'shape mismatch!! {anchor_locations.shape,num_events_since_last_3D_update}'
#      78     activated_index = 0
#
# Cell In[9], line 19, in add_new_LEFBonds(sim1D, sim3D, nsteps)
#      16 leids = np.array(leids, dtype=str)
#      17 unique_anchor_locs = list(map(list, set(map(tuple, anchor_locs.reshape(-1,2)))))
# ---> 19 sim3D.force_field_manager.removeForce("LEFBonds")
#      20 sim3D.force_field_manager.addLEFBonds(anchors=unique_anchor_locs)
#      22 # print(f"Total LEF bonds added: {sim3D.forceDict['LEFBond'].getNumBonds()}")
#      23 # for bid in range(sim3D.forceDict["LEFBond"].getNumBonds()):
#      24 #     params=sim3D.forceDict['LEFBond'].getBondParameters(bid)
#      25 #     print('bond params', params)
#
# File ~/Library/CloudStorage/Box-Box/Research_current/ChromatinDynamics/src/Forcefield.py:73, in ForceFieldManager.removeForce(self, forceName)
#      71 self.logger.warning(f"The system does not have force {forceName}!!")
#      72 self.logger.warning(f"The forces applied in the system are: {self.forceDict.keys()}")
# ---> 73 raise ValueError
#
# ValueError:
